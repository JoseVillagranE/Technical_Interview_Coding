# %%
import pandas as pd

# %%
raw_dataset = "./data/CREDITRISK_RAW.xlsx"
score_dataset = "./data/CREDITRISK_SCORE.xlsx"

df = pd.read_excel(raw_dataset)
df_test = pd.read_excel(score_dataset)

# %%
df.head()
# Out:
#    ID    GENERO      RENTA  EDAD  NIV_EDUC   E_CIVIL  COD_OFI COD_COM  \
# 0   1  F          463000.0  55.0  MED       CAS            27     226
# 1   2  F         1200000.0  59.0  MED       CAS           121     226
# 2   3  F          526000.0  49.0  TEC       SEP            59      88
# 3   4  M         1500000.0  47.0  UNV       SEP           138       1
# 4   5  M         2600000.0  41.0  UNV       CAS            60     291
#
#              CIUDAD  Crédito_1  Crédito_2   Crédito_3  Crédito_4  \
# 0  CONCEPCION                0      -4030         0.0     292673
# 1  CONCEPCION                0          0  27797549.0          0
# 2  SANTIAGO                  0     750000         0.0          0
# 3  ARICA                     0     976444         0.0          0
# 4  PUERTO MONTT              0     115440         0.0    4500000
#
#    Monto solicitado  Días de Mora  Monto Deuda Promedio  \
# 0             142.0             0                    81
# ...
